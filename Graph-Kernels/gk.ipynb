# %%
# Network-x imports
from networkx.readwrite.graphml import read_graphml
import networkx as nx

# Graph Kernels import
from grakel.utils import graph_from_networkx
from grakel.kernels import WeisfeilerLehman, VertexHistogram, ShortestPath, RandomWalk, SubgraphMatching, NeighborhoodHash, GraphletSampling, PyramidMatch, SvmTheta

# SVM imports
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import metrics

# general imports
import os
# Out:
# /home/suraj/apps/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.lfw module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Loading

# %%
graphs = list()
labels = list()
tags = {'Bubble': 0, 'Insertion': 1, 'Selection': 2, 'Counting': 3, 'Merge': 4, 'Quick': 5}

for algo in os.listdir('CFG'):
    count = 1
    for file in os.listdir('CFG/'+algo):
        graphs.append(read_graphml('CFG/'+algo+'/'+file))
        labels.append(tags[algo])
        if(count == 700):
            break
        count += 1

# %%
len(graphs), len(labels)
# Out:
# (4200, 4200)

# %%
nx.draw_networkx(graphs[0])

# %%
G_train, G_test, Y_train, Y_test = train_test_split(graphs, labels, test_size=0.20, random_state=42)
len(G_train), len(G_test), len(Y_train), len(Y_test)
# Out:
# (3360, 840, 3360, 840)

# %% [markdown]
# ## Convert Network-X Graph to Adj List Representation of GraKel

# %%
G_train = list(graph_from_networkx(G_train, node_labels_tag='label'))
G_test = list(graph_from_networkx(G_test, node_labels_tag='label'))

# %%
G_train[0]
# Out:
# [{'1000102': {'1000113': 1.0},
#   '1000111': {'1000120': 1.0},
#   '1000113': {'1000111': 1.0},
#   '1000115': {'1000129': 1.0},
#   '1000117': {'1000115': 1.0},
#   '1000118': {'1000117': 1.0},
#   '1000119': {'1000118': 1.0},
#   '1000120': {'1000119': 1.0},
#   '1000124': {'1000134': 1.0},
#   '1000126': {'1000124': 1.0},
#   '1000127': {'1000126': 1.0},
#   '1000128': {'1000127': 1.0},
#   '1000129': {'1000128': 1.0},
#   '1000134': {'1000137': 1.0},
#   '1000137': {'1000143': 1.0, '1000148': 1.0},
#   '1000140': {'1000137': 1.0},
#   '1000142': {'1000140': 1.0},
#   '1000143': {'1000142': 1.0},
#   '1000148': {'1000151': 1.0},
#   '1000151': {'1000162': 1.0, '1000174': 1.0},
#   '1000154': {'1000151': 1.0},
#   '1000157': {'1000170': 1.0},
#   '1000159': {'1000157': 1.0},
#   '1000160': {'1000159': 1.0},
#   '1000162': {'1000160': 1.0},
#   '1000165': {'1000154': 1.0},
#   '1000166': {'1000165': 1.0},
#   '1000168': {'1000166': 1.0},
#   '1000170': {'1000168': 1.0},
#   '1000174': {'1000177': 1.0},
#   '1000177': {'1000183': 1.0, '1000196': 1.0},
#   '1000180': {'1000177': 1.0},
#   '1000182': {'1000180': 1.0},
#   '1000183': {'1000187': 1.0},
#   '1000186': {'1000182': 1.0},
#   '1000187': {'1000192': 1.0},
#   '1000190': {'1000186': 1.0},
#   '1000192': {'1000190': 1.0},
#   '1000196': {'1000199': 1.0},
#   '1000199': {'1000210': 1.0, '1000223': 1.0},
#   '1000202': {'1000199': 1.0},
#   '1000205': {'1000219': 1.0},
#   '1000206': {'1000213': 1.0},
#   '1000208': {'1000206': 1.0},
#   '1000210': {'1000208': 1.0},
#   '1000213': {'1000205': 1.0},
#   '1000216': {'1000202': 1.0},
#   '1000217': {'1000216': 1.0},
#   '1000219': {'1000217': 1.0},
#   '1000223': {'1000226': 1.0},
#   '1000226': {'1000233': 1.0, '1000243': 1.0},
#   '1000229': {'1000226': 1.0},
#   '1000233': {'1000236': 1.0, '1000240': 1.0},
#   '1000236': {'1000240': 1.0},
#   '1000238': {'1000229': 1.0},
#   '1000240': {'1000238': 1.0},
#   '1000243': {'1000245': 1.0},
#   '1000245': {'1000247': 1.0},
#   '1000247': {}},
#  {'1000102': '(METHOD,main)',
#   '1000111': '(scanf,scanf("%d",&n))',
#   '1000113': '(<operator>.addressOf,&n)',
#   '1000115': '(<operator>.assignment,A = malloc(sizeof(short)*n+1))',
#   '1000117': '(malloc,malloc(sizeof(short)*n+1))',
#   '1000118': '(<operator>.addition,sizeof(short)*n+1)',
#   '1000119': '(<operator>.multiplication,sizeof(short)*n)',
#   '1000120': '(<operator>.sizeOf,sizeof(short))',
#   '1000124': '(<operator>.assignment,B = malloc(sizeof(short)*n+1))',
#   '1000126': '(malloc,malloc(sizeof(short)*n+1))',
#   '1000127': '(<operator>.addition,sizeof(short)*n+1)',
#   '1000128': '(<operator>.multiplication,sizeof(short)*n)',
#   '1000129': '(<operator>.sizeOf,sizeof(short))',
#   '1000134': '(<operator>.assignment,i=0)',
#   '1000137': '(<operator>.lessEqualsThan,i<=VMAX)',
#   '1000140': '(<operator>.postIncrement,i++)',
#   '1000142': '(<operator>.assignment,C[i] = 0)',
#   '1000143': '(<operator>.indirectIndexAccess,C[i])',
#   '1000148': '(<operator>.assignment,i=0)',
#   '1000151': '(<operator>.lessThan,i<n)',
#   '1000154': '(<operator>.postIncrement,i++)',
#   '1000157': '(scanf,scanf("%hu",&A[i+1]))',
#   '1000159': '(<operator>.addressOf,&A[i+1])',
#   '1000160': '(<operator>.indirectIndexAccess,A[i+1])',
#   '1000162': '(<operator>.addition,i+1)',
#   '1000165': '(<operator>.postIncrement,C[A[i+1]]++)',
#   '1000166': '(<operator>.indirectIndexAccess,C[A[i+1]])',
#   '1000168': '(<operator>.indirectIndexAccess,A[i+1])',
#   '1000170': '(<operator>.addition,i+1)',
#   '1000174': '(<operator>.assignment,i=1)',
#   '1000177': '(<operator>.lessEqualsThan,i<=VMAX)',
#   '1000180': '(<operator>.postIncrement,i++)',
#   '1000182': '(<operator>.assignment,C[i] = C[i] + C[i-1])',
#   '1000183': '(<operator>.indirectIndexAccess,C[i])',
#   '1000186': '(<operator>.addition,C[i] + C[i-1])',
#   '1000187': '(<operator>.indirectIndexAccess,C[i])',
#   '1000190': '(<operator>.indirectIndexAccess,C[i-1])',
#   '1000192': '(<operator>.subtraction,i-1)',
#   '1000196': '(<operator>.assignment,j=1)',
#   '1000199': '(<operator>.lessEqualsThan,j<=n)',
#   '1000202': '(<operator>.postIncrement,j++)',
#   '1000205': '(<operator>.assignment,B[C[A[j]]] = A[j])',
#   '1000206': '(<operator>.indirectIndexAccess,B[C[A[j]]])',
#   '1000208': '(<operator>.indirectIndexAccess,C[A[j]])',
#   '1000210': '(<operator>.indirectIndexAccess,A[j])',
#   '1000213': '(<operator>.indirectIndexAccess,A[j])',
#   '1000216': '(<operator>.postDecrement,C[A[j]]--)',
#   '1000217': '(<operator>.indirectIndexAccess,C[A[j]])',
#   '1000219': '(<operator>.indirectIndexAccess,A[j])',
#   '1000223': '(<operator>.assignment,i=1)',
#   '1000226': '(<operator>.lessEqualsThan,i<=n)',
#   '1000229': '(<operator>.postIncrement,i++)',
#   '1000233': '(<operator>.greaterThan,i>1)',
#   '1000236': '(printf,printf(" "))',
#   '1000238': '(printf,printf("%d",B[i]))',
#   '1000240': '(<operator>.indirectIndexAccess,B[i])',
#   '1000243': '(printf,printf("\\n"))',
#   '1000245': '(RETURN,return 0;,return 0;)',
#   '1000247': '(METHOD_RETURN,int)'},
#  None]

# %% [markdown]
# # Kernel Computation & SVM

# %% [markdown]
# ## 1. Compute the Weisfeiler Lehman Kernel

# %%
# Initialize a Weisfeiler-Lehman subtree kernel
gk = WeisfeilerLehman()

# %%
# Construct kernel matrices
K_train = gk.fit_transform(G_train)
K_test = gk.transform(G_test)

# %%
K_train
# Out:
# array([[416,  17,  37, ...,  45,   0,   0],
#        [ 17, 366,  16, ...,   7,   6,   6],
#        [ 37,  16, 294, ...,  37,   0,   0],
#        ...,
#        [ 45,   7,  37, ..., 240,   0,   0],
#        [  0,   6,   0, ...,   0,  60,   6],
#        [  0,   6,   0, ...,   0,   6,  54]], dtype=int64)

# %%
# Train an SVM classifier
clf = SVC(kernel='precomputed')
clf.fit(K_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='precomputed', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Test classifier
Y_pred = clf.predict(K_test)

# %%
# Analysis
count = 0
for i in range(len(Y_test)):
    if Y_test[i] != Y_pred[i]:
        count += 1
        print(i+1, Y_test[i], Y_pred[i])
print(count)
# Out:
# 10 3 4
# 15 1 0
# 17 4 2
# 18 2 4
# 23 5 4
# 56 2 1
# 59 5 4
# 83 3 4
# 85 2 4
# 93 4 5
# 109 0 1
# 115 2 1
# 123 4 2
# 125 2 4
# 140 1 0
# 144 0 4
# 148 1 5
# 149 2 0
# 152 2 0
# 156 4 5
# 161 5 4
# 174 5 4
# 193 0 2
# 197 5 4
# 206 5 0
# 213 5 1
# 218 5 2
# 225 2 0
# 228 0 2
# 233 5 4
# 245 1 4
# 247 2 5
# 276 5 4
# 287 5 4
# 299 0 5
# 300 5 4
# 301 1 0
# 302 2 4
# 315 0 2
# 330 0 4
# 344 2 1
# 353 5 2
# 360 1 4
# 361 2 5
# 362 1 2
# 367 5 4
# 369 4 5
# 371 5 4
# 373 1 4
# 382 1 2
# 403 5 4
# 417 2 0
# 421 2 4
# 424 2 4
# 430 0 2
# 438 2 0
# 447 5 2
# 457 2 4
# 462 2 1
# 474 5 4
# 478 1 0
# 479 2 1
# 488 5 4
# 492 3 1
# 499 2 4
# 500 4 5
# 501 4 5
# 512 2 5
# 521 0 4
# 552 0 1
# 555 0 1
# 574 2 4
# 589 0 1
# 594 2 0
# 599 1 0
# 609 2 1
# 610 5 4
# 623 3 2
# 634 3 1
# 646 3 4
# 650 3 4
# 667 0 1
# 668 5 4
# 686 0 2
# 703 2 1
# 704 4 2
# 705 2 0
# 709 2 0
# 717 2 1
# 720 3 4
# 724 4 5
# 732 3 4
# 735 2 4
# 740 1 3
# 743 5 4
# 744 1 0
# 752 1 4
# 758 1 4
# 762 0 1
# 767 1 2
# 768 1 0
# 778 2 1
# 779 4 3
# 785 2 0
# 786 2 4
# 795 4 1
# 806 2 4
# 811 4 3
# 836 2 5
# 838 3 4
# 840 2 0
# 111

# %%
# Kernel Matrix
K_test.shape
# Out:
# (840, 3360)

# %%
graphs1 = list()
labels1 = list()
tags = {'Bubble': 0, 'Insertion': 1, 'Selection': 2, 'Counting': 3, 'Merge': 4, 'Quick': 5}

for algo in os.listdir('CFG'):
    count = 1
    for file in os.listdir('CFG/'+algo):
        graphs1.append(read_graphml('CFG/'+algo+'/'+file))
        labels1.append([tags[algo], file])
        if(count == 700):
            break
        count += 1

# %%
G_train1, G_test1, Y_train1, Y_test1 = train_test_split(graphs1, labels1, test_size=0.20, random_state=42)
len(G_train1), len(G_test1), len(Y_train1), len(Y_test1)
# Out:
# (3360, 840, 3360, 840)

# %%
# Analysis
r_tags = {0: 'Bubble', 1: 'Insertion', 2: 'Selection', 3:'Counting', 4: 'Merge', 5: 'Quick'}
count = 0
for i in range(len(Y_test)):
    if Y_test[i] != Y_pred[i]:
        count += 1
        print(i+1, Y_test1[i], [Y_pred[i], r_tags[Y_pred[i]]])
print(count)
# Out:
# 10 [3, 'counting1979559.graphml'] [4, 'Merge']
# 15 [1, 'insertion3893366.graphml'] [0, 'Bubble']
# 17 [4, 'merge1515388.graphml'] [2, 'Selection']
# 18 [2, 'selection2272079.graphml'] [4, 'Merge']
# 23 [5, 'quick672841.graphml'] [4, 'Merge']
# 56 [2, 'selection3895884.graphml'] [1, 'Insertion']
# 59 [5, 'quick2856923.graphml'] [4, 'Merge']
# 83 [3, 'counting3955982.graphml'] [4, 'Merge']
# 85 [2, 'selection4158811.graphml'] [4, 'Merge']
# 93 [4, 'merge3750272.graphml'] [5, 'Quick']
# 109 [0, 'bubble3275457.graphml'] [1, 'Insertion']
# 115 [2, 'selection3246904.graphml'] [1, 'Insertion']
# 123 [4, 'merge2128156.graphml'] [2, 'Selection']
# 125 [2, 'selection4034930.graphml'] [4, 'Merge']
# 140 [1, 'insertion910198.graphml'] [0, 'Bubble']
# 144 [0, 'bubble1896879.graphml'] [4, 'Merge']
# 148 [1, 'insertion2998924.graphml'] [5, 'Quick']
# 149 [2, 'selection3855765.graphml'] [0, 'Bubble']
# 152 [2, 'selection4659872.graphml'] [0, 'Bubble']
# 156 [4, 'merge4029017.graphml'] [5, 'Quick']
# 161 [5, 'quick4616656.graphml'] [4, 'Merge']
# 174 [5, 'quick3924427.graphml'] [4, 'Merge']
# 193 [0, 'bubble2598511.graphml'] [2, 'Selection']
# 197 [5, 'quick4152114.graphml'] [4, 'Merge']
# 206 [5, 'quick4171236.graphml'] [0, 'Bubble']
# 213 [5, 'quick4000142.graphml'] [1, 'Insertion']
# 218 [5, 'quick4127443.graphml'] [2, 'Selection']
# 225 [2, 'selection1734419.graphml'] [0, 'Bubble']
# 228 [0, 'bubble2928707.graphml'] [2, 'Selection']
# 233 [5, 'quick2999393.graphml'] [4, 'Merge']
# 245 [1, 'insertion1384586.graphml'] [4, 'Merge']
# 247 [2, 'selection3051739.graphml'] [5, 'Quick']
# 276 [5, 'quick3073171.graphml'] [4, 'Merge']
# 287 [5, 'quick4120242.graphml'] [4, 'Merge']
# 299 [0, 'bubble2529536.graphml'] [5, 'Quick']
# 300 [5, 'quick4610743.graphml'] [4, 'Merge']
# 301 [1, 'insertion1210513.graphml'] [0, 'Bubble']
# 302 [2, 'selection2628411.graphml'] [4, 'Merge']
# 315 [0, 'bubble4434530.graphml'] [2, 'Selection']
# 330 [0, 'bubble3909652.graphml'] [4, 'Merge']
# 344 [2, 'selection2809814.graphml'] [1, 'Insertion']
# 353 [5, 'quick2955009.graphml'] [2, 'Selection']
# 360 [1, 'insertion2104277.graphml'] [4, 'Merge']
# 361 [2, 'selection3246921.graphml'] [5, 'Quick']
# 362 [1, 'insertion2583367.graphml'] [2, 'Selection']
# 367 [5, 'quick3738822.graphml'] [4, 'Merge']
# 369 [4, 'merge2833145.graphml'] [5, 'Quick']
# 371 [5, 'quick4173033.graphml'] [4, 'Merge']
# 373 [1, 'insertion1715112.graphml'] [4, 'Merge']
# 382 [1, 'insertion3446110.graphml'] [2, 'Selection']
# 403 [5, 'quick1379392.graphml'] [4, 'Merge']
# 417 [2, 'selection2325123.graphml'] [0, 'Bubble']
# 421 [2, 'selection1427745.graphml'] [4, 'Merge']
# 424 [2, 'selection2594156.graphml'] [4, 'Merge']
# 430 [0, 'bubble4045853.graphml'] [2, 'Selection']
# 438 [2, 'selection4818099.graphml'] [0, 'Bubble']
# 447 [5, 'quick3884151.graphml'] [2, 'Selection']
# 457 [2, 'selection1733579.graphml'] [4, 'Merge']
# 462 [2, 'selection2977258.graphml'] [1, 'Insertion']
# 474 [5, 'quick3085325.graphml'] [4, 'Merge']
# 478 [1, 'insertion3248211.graphml'] [0, 'Bubble']
# 479 [2, 'selection3197861.graphml'] [1, 'Insertion']
# 488 [5, 'quick4139574.graphml'] [4, 'Merge']
# 492 [3, 'counting2992823.graphml'] [1, 'Insertion']
# 499 [2, 'selection918608.graphml'] [4, 'Merge']
# 500 [4, 'merge2609835.graphml'] [5, 'Quick']
# 501 [4, 'merge3295512.graphml'] [5, 'Quick']
# 512 [2, 'selection2271698.graphml'] [5, 'Quick']
# 521 [0, 'bubble3537305.graphml'] [4, 'Merge']
# 552 [0, 'bubble1299882.graphml'] [1, 'Insertion']
# 555 [0, 'bubble3853986.graphml'] [1, 'Insertion']
# 574 [2, 'selection3502184.graphml'] [4, 'Merge']
# 589 [0, 'bubble2362106.graphml'] [1, 'Insertion']
# 594 [2, 'selection3551675.graphml'] [0, 'Bubble']
# 599 [1, 'insertion2933580.graphml'] [0, 'Bubble']
# 609 [2, 'selection906881.graphml'] [1, 'Insertion']
# 610 [5, 'quick4158350.graphml'] [4, 'Merge']
# 623 [3, 'counting881902.graphml'] [2, 'Selection']
# 634 [3, 'counting4152585.graphml'] [1, 'Insertion']
# 646 [3, 'counting3949793.graphml'] [4, 'Merge']
# 650 [3, 'counting2992093.graphml'] [4, 'Merge']
# 667 [0, 'bubble2633703.graphml'] [1, 'Insertion']
# 668 [5, 'quick2479771.graphml'] [4, 'Merge']
# 686 [0, 'bubble4857269.graphml'] [2, 'Selection']
# 703 [2, 'selection3600092.graphml'] [1, 'Insertion']
# 704 [4, 'merge4152567.graphml'] [2, 'Selection']
# 705 [2, 'selection4234703.graphml'] [0, 'Bubble']
# 709 [2, 'selection3923870.graphml'] [0, 'Bubble']
# 717 [2, 'selection3277885.graphml'] [1, 'Insertion']
# 720 [3, 'counting3313288.graphml'] [4, 'Merge']
# 724 [4, 'merge2980256.graphml'] [5, 'Quick']
# 732 [3, 'counting2991796.graphml'] [4, 'Merge']
# 735 [2, 'selection2268762.graphml'] [4, 'Merge']
# 740 [1, 'insertion882140.graphml'] [3, 'Counting']
# 743 [5, 'quick4609396.graphml'] [4, 'Merge']
# 744 [1, 'insertion2941747.graphml'] [0, 'Bubble']
# 752 [1, 'insertion3968585.graphml'] [4, 'Merge']
# 758 [1, 'insertion3614917.graphml'] [4, 'Merge']
# 762 [0, 'bubble2632666.graphml'] [1, 'Insertion']
# 767 [1, 'insertion2806083.graphml'] [2, 'Selection']
# 768 [1, 'insertion4806343.graphml'] [0, 'Bubble']
# 778 [2, 'selection4385234.graphml'] [1, 'Insertion']
# 779 [4, 'merge861675.graphml'] [3, 'Counting']
# 785 [2, 'selection4035839.graphml'] [0, 'Bubble']
# 786 [2, 'selection2064401.graphml'] [4, 'Merge']
# 795 [4, 'merge3002502.graphml'] [1, 'Insertion']
# 806 [2, 'selection1749572.graphml'] [4, 'Merge']
# 811 [4, 'merge1794400.graphml'] [3, 'Counting']
# 836 [2, 'selection917245.graphml'] [5, 'Quick']
# 838 [3, 'counting4133285.graphml'] [4, 'Merge']
# 840 [2, 'selection4045575.graphml'] [0, 'Bubble']
# 111

# %%
# Evaluate the predictions
print("Accuracy:", accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8678571428571429

# %%
print(metrics.confusion_matrix(Y_test, Y_pred))

# Print the precision and recall, among other metrics
print(metrics.classification_report(Y_test, Y_pred, digits=2))
# Out:
# [[115   6   5   0   3   1]
#  [  7  93   3   1   5   1]
#  [ 10   9 128   0  12   4]
#  [  0   2   1 146   7   0]
#  [  0   1   3   2 125   6]
#  [  1   1   3   0  17 122]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       130
#            1       0.83      0.85      0.84       110
#            2       0.90      0.79      0.84       163
#            3       0.98      0.94      0.96       156
#            4       0.74      0.91      0.82       137
#            5       0.91      0.85      0.88       144
#
#     accuracy                           0.87       840
#    macro avg       0.87      0.87      0.87       840
# weighted avg       0.87      0.87      0.87       840

# %%
K_train.shape
# Out:
# (3360, 3360)

# %% [markdown]
# ## 2. The random walk kernel class (Time Consuming)

# %%
gk = RandomWalk()

# %%
# Construct kernel matrices
K_train = gk.fit_transform(G_train)
K_test = gk.transform(G_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0a79bba0463b> in <module>
#       1 # Construct kernel matrices
# ----> 2 K_train = gk.fit_transform(G_train)
#       3 K_test = gk.transform(G_test)
#
# ~/apps/anaconda3/lib/python3.7/site-packages/grakel-0.1b7-py3.7-linux-x86_64.egg/grakel/kernels/kernel.py in fit_transform(self, X)
#     195
#     196         # Transform - calculate kernel matrix
# --> 197         km = self._calculate_kernel_matrix()
#     198
#     199         self._X_diag = np.diagonal(km)
#
# ~/apps/anaconda3/lib/python3.7/site-packages/grakel-0.1b7-py3.7-linux-x86_64.egg/grakel/kernels/kernel.py in _calculate_kernel_matrix(self, Y)
#     231                     K[i, i] = self.pairwise_operation(x, x)
#     232                     for (j, y) in enumerate(cache):
# --> 233                         K[j, i] = self.pairwise_operation(y, x)
#     234                     cache.append(x)
#     235             else:
#
# ~/apps/anaconda3/lib/python3.7/site-packages/grakel-0.1b7-py3.7-linux-x86_64.egg/grakel/kernels/random_walk.py in pairwise_operation(self, X, Y)
#     269             A = LinearOperator((mn, mn), matvec=lambda x: lsf(x, self.lamda))
#     270             b = np.ones(mn)
# --> 271             x_sol, _ = cg(A, b, tol=1.0e-6, maxiter=20, atol='legacy')
#     272             return np.sum(x_sol)
#     273
#
# ~/apps/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/isolve/iterative.py in cg(A, b, x0, tol, maxiter, M, callback, atol)
#
# ~/apps/anaconda3/lib/python3.7/site-packages/scipy/_lib/_threadsafety.py in caller(func, *a, **kw)
#      44         def caller(func, *a, **kw):
#      45             with self:
# ---> 46                 return func(*a, **kw)
#      47         return scipy._lib.decorator.decorate(func, caller)
#      48
#
# ~/apps/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/isolve/iterative.py in cg(A, b, x0, tol, maxiter, M, callback, atol)
#     313         elif (ijob == 1):
#     314             work[slice2] *= sclr2
# --> 315             work[slice2] += sclr1*matvec(work[slice1])
#     316         elif (ijob == 2):
#     317             work[slice1] = psolve(work[slice2])
#
# ~/apps/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/interface.py in matvec(self, x)
#     227             raise ValueError('dimension mismatch')
#     228
# --> 229         y = self._matvec(x)
#     230
#     231         if isinstance(x, np.matrix):
#
# ~/apps/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/interface.py in _matvec(self, x)
#     525
#     526     def _matvec(self, x):
# --> 527         return self.__matvec_impl(x)
#     528
#     529     def _rmatvec(self, x):
#
# ~/apps/anaconda3/lib/python3.7/site-packages/grakel-0.1b7-py3.7-linux-x86_64.egg/grakel/kernels/random_walk.py in <lambda>(x)
#     267
#     268             # A*x=b
# --> 269             A = LinearOperator((mn, mn), matvec=lambda x: lsf(x, self.lamda))
#     270             b = np.ones(mn)
#     271             x_sol, _ = cg(A, b, tol=1.0e-6, maxiter=20, atol='legacy')
#
# ~/apps/anaconda3/lib/python3.7/site-packages/grakel-0.1b7-py3.7-linux-x86_64.egg/grakel/kernels/random_walk.py in lsf(x, lamda)
#     262
#     263             def lsf(x, lamda):
# --> 264                 xm = x.reshape((xs, ys), order='F')
#     265                 y = np.reshape(multi_dot((Ax, xm, Ay)), (mn,), order='F')
#     266                 return x - self.lamda * y
#
# KeyboardInterrupt:

# %%
# Train an SVM classifier
clf = SVC(kernel='precomputed')
clf.fit(K_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='precomputed', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Test classifier
Y_pred = clf.predict(K_test)

# %%
print(metrics.confusion_matrix(Y_test, Y_pred))

# Print the precision and recall, among other metrics
print(metrics.classification_report(Y_test, Y_pred, digits=2))
# Out:
# [[46 19 35  2 18 10]
#  [ 8 69 15  4 14  0]
#  [21 24 85  0 25  8]
#  [10 35 11 71 10 19]
#  [ 3 29  1  0 65 39]
#  [ 0  2  1  7 59 75]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.35      0.42       130
#            1       0.39      0.63      0.48       110
#            2       0.57      0.52      0.55       163
#            3       0.85      0.46      0.59       156
#            4       0.34      0.47      0.40       137
#            5       0.50      0.52      0.51       144
#
#     accuracy                           0.49       840
#    macro avg       0.53      0.49      0.49       840
# weighted avg       0.54      0.49      0.50       840

# %% [markdown]
# ## 3. Subgraph Matching

# %%
gk = SubgraphMatching(ke=None)

# %%
# Construct kernel matrices
K_train = gk.fit_transform(G_train)
K_test = gk.transform(G_test)

# %%
# Train an SVM classifier
clf = SVC(kernel='precomputed')
clf.fit(K_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='precomputed', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Test classifier
Y_pred = clf.predict(K_test)

# %%
print(metrics.confusion_matrix(Y_test, Y_pred))

# Print the precision and recall, among other metrics
print(metrics.classification_report(Y_test, Y_pred, digits=2))
# Out:
# [[110   5   8   1   4   2]
#  [ 10  90   3   2   5   0]
#  [ 14  15 123   2   8   1]
#  [  0   2   1 147   6   0]
#  [  2   1   2   1 126   5]
#  [  3   3   2   0  16 120]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       130
#            1       0.78      0.82      0.80       110
#            2       0.88      0.75      0.81       163
#            3       0.96      0.94      0.95       156
#            4       0.76      0.92      0.83       137
#            5       0.94      0.83      0.88       144
#
#     accuracy                           0.85       840
#    macro avg       0.85      0.85      0.85       840
# weighted avg       0.86      0.85      0.85       840

# %% [markdown]
# ## 4. NeighborhoodHash Kernel

# %%
gk = NeighborhoodHash()

# %%
# Construct kernel matrices
K_train = gk.fit_transform(G_train)
K_test = gk.transform(G_test)
# Out:
# /home/suraj/apps/anaconda3/lib/python3.7/site-packages/grakel-0.1b7-py3.7-linux-x86_64.egg/grakel/kernels/neighborhood_hash.py:170: UserWarning: Number of labels is smaller thanthe biggest possible.. Collisions will appear on the new labels.
#   warnings.warn('Number of labels is smaller than'

# %%
# Train an SVM classifier
clf = SVC(kernel='precomputed')
clf.fit(K_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='precomputed', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Test classifier
Y_pred = clf.predict(K_test)

# %%
print(metrics.confusion_matrix(Y_test, Y_pred))

# Print the precision and recall, among other metrics
print(metrics.classification_report(Y_test, Y_pred, digits=2))
# Out:
# [[106   7   7   0   7   3]
#  [  7  94   2   0   2   5]
#  [  9  10 116   0  18  10]
#  [  4   4   0 138   7   3]
#  [  4   3   2   1 116  11]
#  [  3   0   0   0  17 124]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       130
#            1       0.80      0.85      0.82       110
#            2       0.91      0.71      0.80       163
#            3       0.99      0.88      0.94       156
#            4       0.69      0.85      0.76       137
#            5       0.79      0.86      0.83       144
#
#     accuracy                           0.83       840
#    macro avg       0.83      0.83      0.83       840
# weighted avg       0.84      0.83      0.83       840

# %% [markdown]
# ## 5.  GraphletSampling Kernel

# %%
gk = GraphletSampling()

# %%
# Construct kernel matrices
K_train = gk.fit_transform(G_train)
K_test = gk.transform(G_test)

# %%
# Train an SVM classifier
clf = SVC(kernel='precomputed')
clf.fit(K_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='precomputed', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Test classifier
Y_pred = clf.predict(K_test)

# %%
print(metrics.confusion_matrix(Y_test, Y_pred))

# Print the precision and recall, among other metrics
print(metrics.classification_report(Y_test, Y_pred, digits=2))
# Out:
# [[103   4   8   2   9   4]
#  [ 10  85   4   1   7   3]
#  [ 17   7 120   0  11   8]
#  [ 10   5   3 132   5   1]
#  [  7   3   2   2  84  39]
#  [  4   6   0   0   7 127]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73       130
#            1       0.77      0.77      0.77       110
#            2       0.88      0.74      0.80       163
#            3       0.96      0.85      0.90       156
#            4       0.68      0.61      0.65       137
#            5       0.70      0.88      0.78       144
#
#     accuracy                           0.78       840
#    macro avg       0.78      0.77      0.77       840
# weighted avg       0.79      0.78      0.78       840

# %% [markdown]
# ## 6. SvmTheta Match

# %%
gk = SvmTheta()

# %%
# Construct kernel matrices
K_train = gk.fit_transform(G_train)
K_test = gk.transform(G_test)

# %%
# Train an SVM classifier
clf = SVC(kernel='precomputed')
clf.fit(K_train, Y_train)
